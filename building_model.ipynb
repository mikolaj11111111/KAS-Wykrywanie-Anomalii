# %%
# !pip install anomalib
# Out:
# Collecting anomalib
#   Downloading anomalib-2.2.0-py3-none-any.whl.metadata (33 kB)
# Requirement already satisfied: docstring-parser in /usr/local/lib/python3.12/dist-packages (from anomalib) (0.17.0)
# Requirement already satisfied: einops>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from anomalib) (0.8.1)
# Collecting freia>=0.2 (from anomalib)
#   Downloading FrEIA-0.2.tar.gz (34 kB)
#   Preparing metadata (setup.py) ... done
# Collecting imagecodecs (from anomalib)
#   Downloading imagecodecs-2025.11.11-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (20 kB)
# Collecting jsonargparse>=4.27.7 (from jsonargparse[signatures]>=4.27.7->anomalib)
#   Downloading jsonargparse-4.44.0-py3-none-any.whl.metadata (12 kB)
# Collecting kornia>=0.6.6 (from anomalib)
#   Downloading kornia-0.8.2-py2.py3-none-any.whl.metadata (18 kB)
# Collecting lightning-utilities (from anomalib)
#   Downloading lightning_utilities-0.15.2-py3-none-any.whl.metadata (5.7 kB)
# Collecting lightning>=2.2 (from anomalib)
#   Downloading lightning-2.6.0-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.4.3 in /usr/local/lib/python3.12/dist-packages (from anomalib) (3.10.0)
# Requirement already satisfied: omegaconf>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from anomalib) (2.3.0)
# Requirement already satisfied: opencv-python>=4.5.3.56 in /usr/local/lib/python3.12/dist-packages (from anomalib) (4.12.0.88)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from anomalib) (2.2.2)
# Requirement already satisfied: pillow>=10.1.0 in /usr/local/lib/python3.12/dist-packages (from anomalib) (11.3.0)
# Collecting rich-argparse (from anomalib)
#   Downloading rich_argparse-1.7.2-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: rich>=13.5.2 in /usr/local/lib/python3.12/dist-packages (from anomalib) (13.9.4)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from anomalib) (0.25.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from anomalib) (1.6.1)
# Requirement already satisfied: tifffile in /usr/local/lib/python3.12/dist-packages (from anomalib) (2025.10.16)
# Requirement already satisfied: timm in /usr/local/lib/python3.12/dist-packages (from anomalib) (1.0.22)
# Collecting torchmetrics>=1.8.2 (from anomalib)
#   Downloading torchmetrics-1.8.2-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.12/dist-packages (from freia>=0.2->anomalib) (2.0.2)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.12/dist-packages (from freia>=0.2->anomalib) (1.16.3)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from freia>=0.2->anomalib) (2.9.0+cu126)
# Requirement already satisfied: PyYAML>=3.13 in /usr/local/lib/python3.12/dist-packages (from jsonargparse>=4.27.7->jsonargparse[signatures]>=4.27.7->anomalib) (6.0.3)
# Collecting typeshed-client>=2.8.2 (from jsonargparse[signatures]>=4.27.7->anomalib)
#   Downloading typeshed_client-2.8.2-py3-none-any.whl.metadata (9.9 kB)
# Collecting kornia_rs>=0.1.9 (from kornia>=0.6.6->anomalib)
#   Downloading kornia_rs-0.1.10-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from kornia>=0.6.6->anomalib) (25.0)
# Requirement already satisfied: fsspec<2027.0,>=2022.5.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<2027.0,>=2022.5.0->lightning>=2.2->anomalib) (2025.3.0)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in /usr/local/lib/python3.12/dist-packages (from lightning>=2.2->anomalib) (4.67.1)
# Requirement already satisfied: typing-extensions<6.0,>4.5.0 in /usr/local/lib/python3.12/dist-packages (from lightning>=2.2->anomalib) (4.15.0)
# Collecting pytorch-lightning (from lightning>=2.2->anomalib)
#   Downloading pytorch_lightning-2.6.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from lightning-utilities->anomalib) (75.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.4.3->anomalib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.4.3->anomalib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.4.3->anomalib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.4.3->anomalib) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.4.3->anomalib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.4.3->anomalib) (2.9.0.post0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from omegaconf>=2.1.1->anomalib) (4.9.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.0->anomalib) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.0->anomalib) (2025.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.5.2->anomalib) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.5.2->anomalib) (2.19.2)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image->anomalib) (3.6)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->anomalib) (2.37.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->anomalib) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->anomalib) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->anomalib) (3.6.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from timm->anomalib) (0.24.0+cu126)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (from timm->anomalib) (0.36.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from timm->anomalib) (0.7.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<2027.0,>=2022.5.0->lightning>=2.2->anomalib) (3.13.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.5.2->anomalib) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.4.3->anomalib) (1.17.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->freia>=0.2->anomalib) (3.20.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->freia>=0.2->anomalib) (1.14.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->freia>=0.2->anomalib) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->freia>=0.2->anomalib) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->freia>=0.2->anomalib) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->freia>=0.2->anomalib) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->freia>=0.2->anomalib) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->freia>=0.2->anomalib) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->freia>=0.2->anomalib) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->freia>=0.2->anomalib) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->freia>=0.2->anomalib) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->freia>=0.2->anomalib) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->freia>=0.2->anomalib) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->freia>=0.2->anomalib) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->freia>=0.2->anomalib) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->freia>=0.2->anomalib) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->freia>=0.2->anomalib) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->freia>=0.2->anomalib) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->freia>=0.2->anomalib) (3.5.0)
# Requirement already satisfied: importlib_resources>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from typeshed-client>=2.8.2->jsonargparse[signatures]>=4.27.7->anomalib) (6.5.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm->anomalib) (2.32.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm->anomalib) (1.2.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.2->anomalib) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.2->anomalib) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.2->anomalib) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.2->anomalib) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.2->anomalib) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.2->anomalib) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.2->anomalib) (1.22.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.0.0->freia>=0.2->anomalib) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.0.0->freia>=0.2->anomalib) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->timm->anomalib) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->timm->anomalib) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->timm->anomalib) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->timm->anomalib) (2025.11.12)
# Downloading anomalib-2.2.0-py3-none-any.whl (851 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 851.8/851.8 kB 18.2 MB/s eta 0:00:00
# Downloading jsonargparse-4.44.0-py3-none-any.whl (241 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.8/241.8 kB 20.2 MB/s eta 0:00:00
# Downloading kornia-0.8.2-py2.py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 49.0 MB/s eta 0:00:00
# Downloading lightning-2.6.0-py3-none-any.whl (845 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 846.0/846.0 kB 45.8 MB/s eta 0:00:00
# Downloading lightning_utilities-0.15.2-py3-none-any.whl (29 kB)
# Downloading torchmetrics-1.8.2-py3-none-any.whl (983 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 56.4 MB/s eta 0:00:00
# Downloading imagecodecs-2025.11.11-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (23.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.2/23.2 MB 49.3 MB/s eta 0:00:00
# Downloading rich_argparse-1.7.2-py3-none-any.whl (25 kB)
# Downloading kornia_rs-0.1.10-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 61.9 MB/s eta 0:00:00
# Downloading typeshed_client-2.8.2-py3-none-any.whl (760 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 760.5/760.5 kB 36.4 MB/s eta 0:00:00
# Downloading pytorch_lightning-2.6.0-py3-none-any.whl (849 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.5/849.5 kB 43.1 MB/s eta 0:00:00
# Building wheels for collected packages: freia
#   Building wheel for freia (setup.py) ... done
#   Created wheel for freia: filename=FrEIA-0.2-py3-none-any.whl size=42763 sha256=0fbcf9f5795c44b8a7ab2e10ea523439573ec88a9b68ed326a86c4da2c1b5f65
#   Stored in directory: /root/.cache/pip/wheels/ae/40/63/f30f17a00a5c53f982c5c222995b53fe1ee510d2ea13b00856
# Successfully built freia
# Installing collected packages: typeshed-client, lightning-utilities, kornia_rs, jsonargparse, imagecodecs, rich-argparse, torchmetrics, kornia, freia, pytorch-lightning, lightning, anomalib
# Successfully installed anomalib-2.2.0 freia-0.2 imagecodecs-2025.11.11 jsonargparse-4.44.0 kornia-0.8.2 kornia_rs-0.1.10 lightning-2.6.0 lightning-utilities-0.15.2 pytorch-lightning-2.6.0 rich-argparse-1.7.2 torchmetrics-1.8.2 typeshed-client-2.8.2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import csv
import os
from datetime import datetime
from pathlib import Path
import torch
import cv2
from torchmetrics.classification import BinaryConfusionMatrix
from anomalib.models import Padim, Cfa, Patchcore, Fastflow
from anomalib.models.image.cfa.torch_model import CfaModel
from anomalib.engine import Engine
from anomalib.data import Folder
from torchmetrics.classification import (
    BinaryAccuracy,
    BinaryPrecision,
    BinaryRecall,
    BinaryConfusionMatrix
)

MODEL_NAME = "Padim"
BACKBONE = "resnet18"
LAYERS = ["layer1", "layer2", "layer3", "layer4"]
EPOCHS = 25
CSV_FILENAME = "/content/drive/MyDrive/Hacknation/experiment_results_color_augmanted.csv"
OUTPUT_DIR = "/content/drive/MyDrive/Hacknation/visualizations"

# %%
def save_results_to_csv(test_results):
    """
    Zapisuje wyniki, architekturę i parametry do pliku CSV.
    """
    metrics = test_results[0]

    auroc = metrics.get('image_AUROC', 0.0)
    f1_score = metrics.get('image_F1Score', 0.0)



    row = [
        datetime.now().strftime("%Y-%m-%d %H:%M:%S"), # Data i czas
        MODEL_NAME,                                   # Nazwa modelu
        BACKBONE,                                     # Architektura (Backbone)
        str(LAYERS),                                  # Użyte warstwy
        len(LAYERS),                                  # Ilość warstw
        EPOCHS,                                       #EPOCHS
        round(auroc, 4),                              # AUROC (zaokrąglony)
        round(f1_score, 4)                            # F1 Score (zaokrąglony)
    ]

    file_exists = os.path.isfile(CSV_FILENAME)

    try:
        with open(CSV_FILENAME, mode='a', newline='', encoding='utf-8') as f:
            writer = csv.writer(f)

            # Jeśli plik jest nowy, dodaj nagłówek
            if not file_exists:
                header = ["Timestamp", "Model", "Backbone", "Layers_List", "Layers_Count", "Epochs", "AUROC", "F1Score"]
                writer.writerow(header)

            # Zapisz dane
            writer.writerow(row)
            print(f"\n[INFO] Wyniki zapisano do pliku: {CSV_FILENAME}")
            print(f"[INFO] AUROC: {round(auroc, 4)} | F1: {round(f1_score, 4)}")

    except Exception as e:
        print(f"[ERROR] Nie udało się zapisać do CSV: {e}")

# %%
def train_and_predict():
    # Konfiguracja DataModule
    datamodule = Folder(
        name="hackathon_dataset",
        root='/content/drive/MyDrive/Hacknation',
        normal_dir="train/good",
        abnormal_dir="test/bad",
        train_batch_size=4,
        eval_batch_size=4,
        num_workers=8,
    )
    datamodule.setup()

    #Patchcore
    model = Padim(
        backbone=BACKBONE,
        layers=LAYERS,
        pre_trained=True
    )

    engine = Engine(
        max_epochs=EPOCHS,
        devices=1
    )

    print("Rozpoczynam trening...")
    engine.fit(model=model, datamodule=datamodule)

    print("Rozpoczynam testowanie...")
    test_results = engine.test(model=model, datamodule=datamodule)

    save_results_to_csv(test_results)
    model_path = "/content/drive/MyDrive/Hacknation/saved_models/padim_resnet18_final.ckpt"
    engine.trainer.save_checkpoint(model_path)
    print(f"Model zapisany w: {model_path}")
    return engine, model

# %%
train_and_predict()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/46.8M [00:00<?, ?B/s]
# INFO:lightning_fabric.utilities.rank_zero:GPU available: False, used: False
# INFO:lightning_fabric.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:lightning_fabric.utilities.rank_zero:`Trainer(val_check_interval=1.0)` was configured so validation will run at the end of the training epoch..
# Rozpoczynam trening...
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/core/optimizer.py:183: `LightningModule.configure_optimizers` returned `None`, this fit will run with no optimizer
# ┏━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name           ┃ Type          ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ pre_processor  │ PreProcessor  │      0 │ train │     0 │
# │ 1 │ post_processor │ PostProcessor │      0 │ train │     0 │
# │ 2 │ evaluator      │ Evaluator     │      0 │ train │     0 │
# │ 3 │ model          │ PadimModel    │ 11.2 M │ train │     0 │
# └───┴────────────────┴───────────────┴────────┴───────┴───────┘
# Trainable params: 11.2 M
# Non-trainable params: 0
# Total params: 11.2 M
# Total estimated model params size (MB): 44
# Modules in train mode: 19
# Modules in eval mode: 91
# Total FLOPs: 0
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Output()
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/loops/fit_loop.py:534: Found 91 module(s) in eval mode at the start of training. This may lead to unexpected behavior during training. If this is intentional, you can ignore this warning.
# INFO:lightning_fabric.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=1` reached.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# INFO:lightning_fabric.utilities.rank_zero:The following callbacks returned in `LightningModule.configure_callbacks` will override existing callbacks passed to Trainer: Evaluator, ImageVisualizer, PostProcessor, PreProcessor
# Rozpoczynam testowanie...
# Output()
# /usr/local/lib/python3.12/dist-packages/torchmetrics/utilities/prints.py:43: UserWarning: The ``compute`` method of
# metric AUROC was called before the ``update`` method which may lead to errors, as metric states have not yet been
# updated.
#   warnings.warn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torchmetrics/utilities/prints.py:43: UserWarning: The ``compute`` method of
# metric F1Score was called before the ``update`` method which may lead to errors, as metric states have not yet been
# updated.
#   warnings.warn(*args, **kwargs)
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │        image_AUROC        │    0.8121621608734131     │
# │       image_F1Score       │    0.9736841917037964     │
# └───────────────────────────┴───────────────────────────┘
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# INFO: `weights_only` was not set, defaulting to `False`.
# INFO:lightning.pytorch.trainer.connectors.checkpoint_connector:`weights_only` was not set, defaulting to `False`.
# [INFO] Wyniki zapisano do pliku: /content/drive/MyDrive/Hacknation/experiment_results_color_augmanted.csv
# [INFO] AUROC: 0.8122 | F1: 0.9737
# Model zapisany w: /content/drive/MyDrive/Hacknation/saved_models/padim_resnet18_final.ckpt
# (<anomalib.engine.engine.Engine at 0x7e40372f5ee0>,
#  Padim(
#    (pre_processor): PreProcessor(
#      (transform): Compose(
#            Resize(size=[256, 256], interpolation=InterpolationMode.BILINEAR, antialias=True)
#            Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225], inplace=False)
#      )
#      (export_transform): Compose(
#            Resize(size=[256, 256], interpolation=InterpolationMode.BILINEAR, antialias=False)
#            Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225], inplace=False)
#      )
#    )
#    (post_processor): PostProcessor(
#      (_image_threshold_metric): F1AdaptiveThreshold()
#      (_pixel_threshold_metric): F1AdaptiveThreshold()
#      (_image_min_max_metric): MinMax()
#      (_pixel_min_max_metric): MinMax()
#    )
#    (evaluator): Evaluator(
#      (val_metrics): ModuleList()
#      (test_metrics): ModuleList(
#        (0): AUROC()
#        (1): F1Score()
#        (2): AUROC()
#        (3): F1Score()
#      )
#    )
#    (model): PadimModel(
#      (feature_extractor): TimmFeatureExtractor(
#        (feature_extractor): FeatureListNet(
#          (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#          (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#          (act1): ReLU(inplace=True)
#          (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#          (layer1): Sequential(
#            (0): BasicBlock(
#              (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#              (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              (drop_block): Identity()
#              (act1): ReLU(inplace=True)
#              (aa): Identity()
#              (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#              (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              (act2): ReLU(inplace=True)
#            )
#            (1): BasicBlock(
#              (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#              (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              (drop_block): Identity()
#              (act1): ReLU(inplace=True)
#              (aa): Identity()
#              (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#              (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              (act2): ReLU(inplace=True)
#            )
#          )
#          (layer2): Sequential(
#            (0): BasicBlock(
#              (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#              (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              (drop_block): Identity()
#              (act1): ReLU(inplace=True)
#              (aa): Identity()
#              (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#              (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              (act2): ReLU(inplace=True)
#              (downsample): Sequential(
#                (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              )
#            )
#            (1): BasicBlock(
#              (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#              (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              (drop_block): Identity()
#              (act1): ReLU(inplace=True)
#              (aa): Identity()
#              (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#              (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              (act2): ReLU(inplace=True)
#            )
#          )
#          (layer3): Sequential(
#            (0): BasicBlock(
#              (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#              (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              (drop_block): Identity()
#              (act1): ReLU(inplace=True)
#              (aa): Identity()
#              (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#              (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              (act2): ReLU(inplace=True)
#              (downsample): Sequential(
#                (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              )
#            )
#            (1): BasicBlock(
#              (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#              (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              (drop_block): Identity()
#              (act1): ReLU(inplace=True)
#              (aa): Identity()
#              (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#              (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              (act2): ReLU(inplace=True)
#            )
#          )
#          (layer4): Sequential(
#            (0): BasicBlock(
#              (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#              (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              (drop_block): Identity()
#              (act1): ReLU(inplace=True)
#              (aa): Identity()
#              (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#              (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              (act2): ReLU(inplace=True)
#              (downsample): Sequential(
#                (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              )
#            )
#            (1): BasicBlock(
#              (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#              (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              (drop_block): Identity()
#              (act1): ReLU(inplace=True)
#              (aa): Identity()
#              (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#              (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              (act2): ReLU(inplace=True)
#            )
#          )
#        )
#      )
#      (anomaly_map_generator): AnomalyMapGenerator(
#        (blur): GaussianBlur2d()
#      )
#      (gaussian): MultiVariateGaussian()
#    )
#  ))

# %%
# !find /content -type d -name "good"
# Out:
# /content/results/Padim/hackathon_dataset/v16/images/good
# /content/results/Padim/hackathon_dataset/v1/images/good
# /content/results/Padim/hackathon_dataset/v15/images/good
# /content/results/Padim/hackathon_dataset/v2/images/good
# /content/results/Padim/hackathon_dataset/v17/images/good
# /content/results/Padim/hackathon_dataset/v5/images/good
# /content/results/Padim/hackathon_dataset/v14/images/good
# /content/results/Padim/hackathon_dataset/v4/images/good
# /content/results/Padim/hackathon_dataset/v13/images/good
# /content/drive/MyDrive/Hacknation/good
# /content/drive/.Encrypted/MyDrive/Hacknation/good

# %%
# !ls drive/MyDrive/Hacknation/visualizations
# Out:
# ls: cannot access 'drive/MyDrive/Hacknation/visualizations': No such file or directory
